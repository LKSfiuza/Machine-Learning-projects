# %% [markdown]
# <a href="https://colab.research.google.com/github/LKSfiuza/Machine-Learning-projects/blob/main/SVM_Machine_Learning_e_Data_Science_com_Python_de_A_a_Z.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SVM

# %% [markdown]
# ## Base plano de saúde

# %%
# !pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly) (1.29.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 66.4 MB/s eta 0:00:00
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed plotly-6.0.0

# %%
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from yellowbrick.regressor import ResidualsPlot

# %%
base_plano_saude2 = pd.read_csv('plano_saude2.csv')
base_plano_saude2.head()
# Out:
#    idade  custo
# 0     18    470
# 1     23    520
# 2     28    630
# 3     33    830
# 4     38   1150

# %%
X_plano_saude2 = base_plano_saude2.iloc[:, 0:1].values
y_plano_saude2 = base_plano_saude2.iloc[:, 1].values

# %%
X_plano_saude2
# Out:
# array([[18],
#        [23],
#        [28],
#        [33],
#        [38],
#        [43],
#        [48],
#        [53],
#        [58],
#        [63]])

# %%
y_plano_saude2
# Out:
# array([  470,   520,   630,   830,  1150,  1530,  2040,  3080,  5100,
#        10100])

# %%
from sklearn.preprocessing import StandardScaler
scaler_x = StandardScaler()
X_plano_saude2_scaled = scaler_x.fit_transform(X_plano_saude2)
scaler_y = StandardScaler()
y_plano_saude2_scaled = scaler_y.fit_transform(y_plano_saude2.reshape(-1, 1))

# %%
X_plano_saude2_scaled
# Out:
# array([[-1.5666989 ],
#        [-1.21854359],
#        [-0.87038828],
#        [-0.52223297],
#        [-0.17407766],
#        [ 0.17407766],
#        [ 0.52223297],
#        [ 0.87038828],
#        [ 1.21854359],
#        [ 1.5666989 ]])

# %%
y_plano_saude2_scaled
# Out:
# array([[-0.72401136],
#        [-0.7065653 ],
#        [-0.66818397],
#        [-0.59839975],
#        [-0.48674498],
#        [-0.35415495],
#        [-0.17620517],
#        [ 0.18667281],
#        [ 0.8914935 ],
#        [ 2.63609918]])

# %%
# Kernel Linear

from sklearn.svm import SVR
regressor_svr_saude = SVR(kernel='linear')
regressor_svr_saude.fit(X_plano_saude2, y_plano_saude2)
# Out:
# SVR(kernel='linear')

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2.ravel(), y = regressor_svr_saude.predict(X_plano_saude2), name = 'Regressor')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="a27f719e-2006-469a-a722-cd92cd4741dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a27f719e-2006-469a-a722-cd92cd4741dd")) {                    Plotly.newPlot(                        "a27f719e-2006-469a-a722-cd92cd4741dd",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"EhccISYrMDU6Pw=="},"xaxis":"x","y":{"dtype":"i2","bdata":"1gEIAnYCPgN+BPoF+AcIDOwTdCc="},"yaxis":"y","type":"scatter"},{"name":"Regressor","x":{"dtype":"i1","bdata":"EhccISYrMDU6Pw=="},"y":{"dtype":"f8","bdata":"IK5H4XoEa0DMzMzMzECAQBiuR+F6wIlArEfhehSgkUBUuB6F61+WQPQoXI\u002fCH5tAmJmZmZnfn0AehetRuE+iQHI9Ctejr6RAwvUoXI8Pp0A="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}, ...

# %%
# Kernel Polinomial

regressor_svr_saudep = SVR(kernel='poly', degree=3)
regressor_svr_saudep.fit(X_plano_saude2, y_plano_saude2)
# Out:
# SVR(kernel='poly')

# %%
grafico = px.scatter(x = X_plano_saude2.ravel(), y = y_plano_saude2)
grafico.add_scatter(x = X_plano_saude2.ravel(), y = regressor_svr_saudep.predict(X_plano_saude2), name = 'Regressor')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="d309ac1f-1b0c-4908-8ebe-919ab82d60b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d309ac1f-1b0c-4908-8ebe-919ab82d60b2")) {                    Plotly.newPlot(                        "d309ac1f-1b0c-4908-8ebe-919ab82d60b2",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"EhccISYrMDU6Pw=="},"xaxis":"x","y":{"dtype":"i2","bdata":"1gEIAnYCPgN+BPoF+AcIDOwTdCc="},"yaxis":"y","type":"scatter"},{"name":"Regressor","x":{"dtype":"i1","bdata":"EhccISYrMDU6Pw=="},"y":{"dtype":"f8","bdata":"1tBNeG7rc0AayPLdHZB7QJSpOi8zr4NAuoCTafcejECXWFaFl8WTQFaBl7\u002fWM5tAPc\u002fwjBFKokDsiUQlMxCoQKki8QNFCa9Ar2UQAh6ps0A="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0 ...

# %%
# Kernel RBF

regressor_svr_sauderbf = SVR(kernel='rbf')
regressor_svr_sauderbf.fit(X_plano_saude2_scaled, y_plano_saude2_scaled.ravel())
# Out:
# SVR()

# %%
grafico = px.scatter(x = X_plano_saude2_scaled.ravel(), y = y_plano_saude2_scaled.ravel())
grafico.add_scatter(x = X_plano_saude2_scaled.ravel(), y = regressor_svr_sauderbf.predict(X_plano_saude2_scaled), name = 'Regressor')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="32d0fc07-6380-45af-b578-197d005c8025" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("32d0fc07-6380-45af-b578-197d005c8025")) {                    Plotly.newPlot(                        "32d0fc07-6380-45af-b578-197d005c8025",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"TFia3jIR+b9X77CQJ3\u002fzv8YMj4U42uu\u002f3Tq86SG24L\u002fSo6U3LUjGv9KjpTctSMY\u002f3Tq86SG24D\u002fGDI+FONrrP1fvsJAnf\u002fM\u002fTFia3jIR+T8="},"xaxis":"x","y":{"dtype":"f8","bdata":"D2AT3Rkr5793CqrULpzmvypOwlvDYeW\u002fzPccOhcm478FqPVu1CbfvweTtIh5qta\u002f6IGfIOSNxr9UT5wB5eTHP72VBmEdh+w\u002fOwGLKrsWBUA="},"yaxis":"y","type":"scatter"},{"name":"Regressor","x":{"dtype":"f8","bdata":"TFia3jIR+b9X77CQJ3\u002fzv8YMj4U42uu\u002f3Tq86SG24L\u002fSo6U3LUjGv9KjpTctSMY\u002f3Tq86SG24D\u002fGDI+FONrrP1fvsJAnf\u002fM\u002fTFia3jIR+T8="},"y":{"dtype":"f8","bdata":"7MGU043z478cAGdL0kDkvxE752PjQuK\u002fUX9u7SDq378N6TF6bJHcv8N0iUzIP9e\u002fWg7NpVZZwb8Z\u002fFBiPMnSP+wkfcK9Uek\u002fa671jFOA8T8="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color ...

# %%
novo = [[40]]
novo = scaler_x.transform(novo)
regressor_svr_sauderbf.predict(novo)
# Out:
# array([-0.42259356])

# %%
scaler_y.inverse_transform(regressor_svr_sauderbf.predict(novo).reshape(-1, 1))
# Out:
# array([[1333.85650748]])

# %% [markdown]
# ## Base preço das casas

# %%
base_casas = pd.read_csv('house_prices.csv')
base_casas.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
X_casas = base_casas.iloc[:, 3:19].values
y_casas = base_casas.iloc[:, 2].values

# %%
from sklearn.model_selection import train_test_split
X_casas_treinamento, X_casas_teste, y_casas_treinamento, y_casas_teste = train_test_split(X_casas, y_casas, test_size=0.3, random_state=0)

# %%
X_casas_treinamento.shape
# Out:
# (15129, 16)

# %%
X_casas_treinamento
# Out:
# array([[ 4.00000e+00,  1.50000e+00,  1.39000e+03, ...,  9.81330e+04,
#          4.77224e+01, -1.22332e+02],
#        [ 3.00000e+00,  1.50000e+00,  1.45000e+03, ...,  9.81330e+04,
#          4.77725e+01, -1.22349e+02],
#        [ 5.00000e+00,  2.75000e+00,  2.86000e+03, ...,  9.80520e+04,
#          4.77082e+01, -1.22104e+02],
#        ...,
#        [ 3.00000e+00,  2.25000e+00,  2.36000e+03, ...,  9.80420e+04,
#          4.73856e+01, -1.22158e+02],
#        [ 4.00000e+00,  2.00000e+00,  2.37000e+03, ...,  9.80010e+04,
#          4.72831e+01, -1.22279e+02],
#        [ 4.00000e+00,  2.25000e+00,  2.38000e+03, ...,  9.80080e+04,
#          4.76126e+01, -1.22120e+02]])

# %%
y_casas_treinamento
# Out:
# array([400000., 430000., 720000., ..., 431000., 411000., 699900.])

# %%
X_casas_teste.shape
# Out:
# (6484, 16)

# %%
from sklearn.preprocessing import StandardScaler
scaler_x_casas = StandardScaler()
X_casas_treinamento_scaled = scaler_x_casas.fit_transform(X_casas_treinamento)

# %%
scaler_y_casas = StandardScaler()
y_casas_treinamento_scaled = scaler_y_casas.fit_transform(y_casas_treinamento.reshape(-1, 1))

# %%
X_casas_treinamento_scaled
# Out:
# array([[ 0.67170039, -0.79711466, -0.74522967, ...,  1.03727271,
#          1.17348387, -0.83797629],
#        [-0.38696772, -0.79711466, -0.68028398, ...,  1.03727271,
#          1.53476983, -0.95879989],
#        [ 1.7303685 ,  0.82292131,  0.84593978, ..., -0.48008241,
#          1.07108346,  0.78248142],
#        ...,
#        [-0.38696772,  0.17490692,  0.30472568, ..., -0.66741021,
#         -1.25528083,  0.3986888 ],
#        [ 0.67170039, -0.14910028,  0.31554996, ..., -1.43545415,
#         -1.99443873, -0.46129094],
#        [ 0.67170039,  0.17490692,  0.32637425, ..., -1.3043247 ,
#          0.38168351,  0.66876509]])

# %%
y_casas_treinamento_scaled
# Out:
# array([[-0.38454326],
#        [-0.3024967 ],
#        [ 0.49062008],
#        ...,
#        [-0.29976181],
#        [-0.35445952],
#        [ 0.43564888]])

# %%
X_casas_teste_scaled = scaler_x_casas.transform(X_casas_teste)
y_casas_teste_scaled = scaler_y_casas.transform(y_casas_teste.reshape(-1, 1))

# %%
X_casas_teste_scaled
# Out:
# array([[-1.44563583, -0.79711466, -0.70193254, ...,  0.88741047,
#          1.17204161, -0.53947092],
#        [ 0.67170039,  1.47093569,  2.80513482, ..., -1.36052304,
#          0.54321655,  0.35604518],
#        [-1.44563583, -1.76913625, -0.69110826, ...,  0.55022044,
#          0.80065984, -1.06540895],
#        ...,
#        [-0.38696772,  0.49891411,  0.07741576, ..., -0.36768574,
#         -0.78077751,  0.88909048],
#        [-0.38696772, -0.47310747, -0.64781113, ..., -0.854738  ,
#         -1.39878563, -0.46839822],
#        [-0.38696772, -1.44512905, -0.82099964, ...,  0.26922876,
#         -1.78603226,  0.22100704]])

# %%
y_casas_teste_scaled
# Out:
# array([[-0.66623646],
#        [ 2.83715179],
#        [ 0.05878167],
#        ...,
#        [-0.43924097],
#        [-0.74554814],
#        [-0.91511104]])

# %%
# SVR RBF

regressor_svr_casas = SVR(kernel='rbf')
regressor_svr_casas.fit(X_casas_treinamento_scaled, y_casas_treinamento_scaled.ravel())
# Out:
# SVR()

# %%
regressor_svr_casas.score(X_casas_treinamento_scaled, y_casas_treinamento_scaled)
# Out:
# 0.8123337393146999

# %%
regressor_svr_casas.score(X_casas_teste_scaled, y_casas_teste_scaled)
# Out:
# 0.7374454724624955

# %%
previsoes_svr_casas = regressor_svr_casas.predict(X_casas_teste_scaled)

# %%
previsoes_svr_casas
# Out:
# array([-0.54571552,  3.46454238,  0.02286424, ..., -0.46405796,
#        -0.91113329, -1.03334346])

# %%
y_casas_teste_scaled
# Out:
# array([[-0.66623646],
#        [ 2.83715179],
#        [ 0.05878167],
#        ...,
#        [-0.43924097],
#        [-0.74554814],
#        [-0.91511104]])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(scaler_y_casas.inverse_transform((y_casas_teste_scaled).reshape(-1,1)), scaler_y_casas.inverse_transform((previsoes_svr_casas).reshape(-1,1)))
# Out:
# 82453.02198930961
